# %%
# in order to iterate over the testset the index must start at 0

# %%
import pandas as pd

# %%
wijnen = pd.DataFrame(pd.read_json("test_samples_prop_120k.json"))

# %%
wijnen
# Out:
#        country                                        description  \
# 4           US  Much like the regular bottling from 2012, this...
# 21          US  A sleek mix of tart berry, stem and herb, alon...
# 25          US  Oak and earth intermingle around robust aromas...
# 35          US  As with many of the Erath 2010 vineyard design...
# 41          US  A stiff, tannic wine, this slowly opens and br...
# ...        ...                                                ...
# 4007   Croatia  Salt air, lemon pith and lemon blossom lead in...
# 5389        US  Effusive aromas of lychee, lemon drop and oran...
# 7619     Italy  Deeply gold-colored, this opens with aromas of...
# 29870   Israel  Fragrant and floral, this Riesling shines with...
# 11196       US  Remarkably inky in color for a Grenache-based ...
#
#                               designation  points  price            province  \
# 4      Vintner's Reserve Wild Child Block      87   65.0              Oregon
# ...

# %%
type(wijnen.wineclass_list[0])
# Out:
# list

# %%
wijnen=wijnen.reset_index(drop=True)

# %%
wijnen.to_pickle('WinesTest.pkl')
